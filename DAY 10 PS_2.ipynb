# %%
# %matplotlib inline
import pandas as pd
#from IPython.core.display import HTML
#css = open('style-table.css').read()+ open('style-notebook.css').read() 3 HTML('<style>{} </style>'.format(css))

# %%
from IPython.core.display import HTML
css = open('style-table.css').read()+ open('style-notebook.css').read() 3 HTML('<style>{} </style>'.format(css))
# Out:
#   Cell In[2], line 2
#     css = open('style-table.css').read()+ open('style-notebook.css').read() 3 HTML('<style>{} </style>'.format(css))
#                                                                             ^
# SyntaxError: invalid syntax

# %%
titles pd.DataFrame.from_csv('data/titles.csv', index_col-None)
titles.head()
# Out:
#   Cell In[3], line 1
#     titles pd.DataFrame.from_csv('data/titles.csv', index_col-None)
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv("titles.csv")
df
# Out:
#                                       title  year
# 0                        Tasveer Mere Sanam  1996
# 1                                  Only You  1994
# 2                      El pueblo del terror  1970
# 3                                   Machine  2007
# 4                                      MARy  2008
# ...                                     ...   ...
# 244909  Black Butterfly in a Colorful World  2018
# 244910        Hua fei hua wu chun man cheng  1980
# 244911                 Nippon dabi katsukyu  1970
# 244912        Under Siege 2: Dark Territory  1995
# 244913            She Must Be Seeing Things  1987
#
# [244914 rows x 2 columns]

# %%
import pandas as pd
df= pd.read_csv("cast.csv") 
df
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3786171                           Foxtrot  1988            Lilja ??risd?ttir
# 3786172  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3786173                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3786174                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3786175                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %% [markdown]
# # what are the ten most common movie names of all time?

# %%
import pandas as pd

# Assuming you have a DataFrame named 'movies' with a 'Title' column
# Replace 'movies.csv' with your dataset file or data source
titles = pd.read_csv('titles.csv')

# Extract the movie names
titles= titles['title']

# Count the occurrences of each movie name
titles_counts = titles.value_counts()

# Get the top ten most common movie names
top_10_common_titles = titles_counts.head(10)

print(top_10_common_titles)
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# The Outsider            12
# Maya                    12
# Temptation              12
# Freedom                 11
# Honeymoon               11
# Othello                 11
# The Three Musketeers    11
# Name: title, dtype: int64

# %% [markdown]
# # Which three years of the 1930s saw the most films released?

# %%
import pandas as pd
titles = pd.read_csv('titles.csv')
release_year = titles['year']
year_counts = release_year.value_counts()
sorted_year = year_counts.sort_values(ascending=False)
top_3_year = sorted_year.head(3)
print(top_3_year)
# Out:
# 2017    11474
# 2016     9440
# 2015     8702
# Name: year, dtype: int64

# %% [markdown]
# # Plot the number of films that have been released each decade over the history of cinema.

# %%
import pandas as pd
import matplotlib.pyplot as plt
titles= pd.read_csv('titles.csv')

release_years = titles['year']
def calculate_decade(year):
    return str(year // 10 * 10) + 's'
titles['Decade'] = release_years.apply(calculate_decade)
decade_counts = titles['Decade'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
decade_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Decade')
plt.ylabel('Number of Films Released')
plt.title('Number of Films Released Each Decade')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Plot the number of "Hamlet" films made each decade.

# %%
import pandas as pd
import matplotlib.pyplot as plt
movies = pd.read_csv('titles.csv')
hamlet_movies = movies[movies['title'] == 'Hamlet']
release_years = hamlet_movies['year']
def calculate_decade(year):
    return str(year // 10 * 10) + 's'
hamlet_movies['Decade'] = release_years.apply(calculate_decade)
decade_counts = hamlet_movies['Decade'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
decade_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Decade')
plt.ylabel('Number of "Hamlet" Films')
plt.title('Number of "Hamlet" Films Made Each Decade')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16128\3717640863.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_movies['Decade'] = release_years.apply(calculate_decade)

# %% [markdown]
# # Plot the number of "Rustler" characters in each decade of the history of film

# %%
import pandas as pd
import matplotlib.pyplot as plt
character= pd.read_csv('cast.csv')

character = character[character['character'] == 'Rustler']

# Extract the film release years
release_years = character['year']

# Function to calculate the decade for a given year
def calculate_decade(year):
    return str(year // 10 * 10) + 's'

# Create a new column for the decade
character['Decade'] = release_years.apply(calculate_decade)

# Group the data by decade and count the number of "Rustler" characters in each decade
decade_counts = character['Decade'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
decade_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Decade')
plt.ylabel('Number of "Rustler" Character')
plt.title('Number of "Rustler" Character in Each Decade')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Plot the number of "Hamlet" characters each decade.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'characters' with 'CharacterName' and 'ReleaseYear' columns
# Replace 'characters.csv' with your dataset file or data source
character= pd.read_csv('cast.csv')

# Filter the dataset to include only characters from "Hamlet" adaptations
hamlet_character = character[character['character'] == 'Hamlet']

# Extract the release years
release_year = hamlet_character['year']

# Function to calculate the decade for a given year
def calculate_decade(year):
    return str(year // 10 * 10) + 's'

# Create a new column for the decade
hamlet_character['Decade'] = release_year.apply(calculate_decade)

# Group the data by decade and count the number of "Hamlet" characters in each decade
decade_counts = hamlet_character['Decade'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
decade_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Decade')
plt.ylabel('Number of "Hamlet" Character')
plt.title('Number of "Hamlet" Character Each Decade')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16128\2496566480.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_character['Decade'] = release_year.apply(calculate_decade)

# %% [markdown]
# # What are the 11 most common character names in movie history?

# %%
import pandas as pd
characters = pd.read_csv('cast.csv')
character['character'] = character['character'].str.strip().str.lower()
character_counts = character['character'].value_counts()
top_11_common_character = character_counts.head(11)
print(top_11_common_character)
# Out:
# rustler    134
# Name: character, dtype: int64

# %% [markdown]
# # Who are the 10 people most often credited as "Herself" in film history?

# %%
import pandas as pd
n = pd.read_csv('cast.csv')
herself_n = n[n['n'] == 'Herself']
herself_counts = herself_n['title'].value_counts()
top_10_herself_n = herself_counts.head(10)

print(top_10_herself_n)
# Out:
# Series([], Name: title, dtype: int64)

# %% [markdown]
# # Who are the 10 people most often credited as "Himself" In film history?

# %%
import pandas as pd
credits = pd.read_csv('cast.csv')
himself_credits = credits[credits['n'] == 'Himself']
himself_counts = himself_credits['name'].value_counts()
top_10_himself_credits = himself_counts.head(10)

print(top_10_himself_credits)
# Out:
# Series([], Name: name, dtype: int64)

# %% [markdown]
# # Which actors or actresses appeared in the most movies in the year 1945?

# %%
import pandas as pd

# Load your movie dataset
# Replace 'movies.csv' with your dataset file or data source
type = pd.read_csv('cast.csv')

# Filter the dataset to include only movies released in 1945
movies_1945 = movies[movies['year'] == 1945]

# Create an empty dictionary to store actor/actress appearance counts
appearances = {}

# Iterate through each row (movie) in the filtered dataset
for index, movie in movies_1945.iterrows():
    # Extract the cast information for the movie (modify this depending on your dataset structure)
    type = movie['cast'].split(', ')
    
    # Count the appearance of each actor/actress
    for actor in cast:
        if actor in appearances:
            appearances[actor] += 1
        else:
            appearances[actor] = 1

# Find the actors/actresses with the most appearances in 1945
most_appearances = max(appearances, key=appearances.get)

print(f"The actor/actress with the most appearances in 1945 was: {most_appearances} ({appearances[most_appearances]} appearances)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cast'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Plot how many roles Mammootty has played in each year of his career

# %%
name = pd.read_csv('cast.csv')

# Filter the dataset to include only movies with Mammootty
mammootty_movies = movies[movies['actor'] == 'mammootty']

# Extract release years and roles
release_years = mammootty_movies['year']
character = mammootty_movies['character']

# Count the number of roles he played in each year
roles_per_year = release_years.value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(12, 6))
plt.plot(roles_per_year.index, roles_per_year.values, marker='o', linestyle='-')
plt.xlabel('year')
plt.ylabel('Number of Roles')
plt.title('Number of Roles Played by Mammootty Each Year')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'actor'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # What are the 10 most frequent roles that start with the phrase "Patron"

# %%
patron_roles = characters[characters['character'].str.startswith("Patron")]

# Count the occurrences of each unique role
patron_role_counts = patron_roles['character'].value_counts()

# Select the top 10 most frequent roles
top_10_patron_roles = patron_role_counts.head(10)

print(top_10_patron_roles)
# Out:
# Patron                     587
# Patron at Bar               33
# Patron #1                   26
# Patron #2                   24
# Patron in Frisky Rabbit     16
# Patron 1                    15
# Patron at Jollie's LIVE     14
# Patrona                     14
# Patron 2                    11
# Patron of Cafe Europa       11
# Name: character, dtype: int64

# %% [markdown]
# # What are the 10 most frequent roles that start with the word "Sclence"

# %%
science_roles = characters[characters['character'].str.startswith("science")]

# Count the occurrences of each unique role
science_role_counts = science_roles['character'].value_counts()

# Select the top 10 most frequent roles
top_10_science_roles = science_role_counts.head(10)

print(top_10_science_roles)
# Out:
# science chick interviewee                 1
# science chick questioneer Josette Ruby    1
# Name: character, dtype: int64

# %% [markdown]
# # Plot the n-values of the roles that Judi Dench has played over her career

# %%
judi_dench_roles = characters[characters['character'] == 'Judi Dench']

# Count the occurrences of each unique role
role_counts = judi_dench_roles['character'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
role_counts.plot(kind='bar', color='skyblue')
plt.xlabel('character')
plt.ylabel('Number of Occurrences')
plt.title('Number of Occurrences of Roles Played by Judi Dench')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 8
#       6 # Create a bar plot
#       7 plt.figure(figsize=(12, 6))
# ----> 8 role_counts.plot(kind='bar', color='skyblue')
#       9 plt.xlabel('character')
#      10 plt.ylabel('Number of Occurrences')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %% [markdown]
# # Plot the n-values of Cary Grant's roles through his career.

# %%
cary_grant_roles = characters[characters['character'] == 'Cary Grant']

# Count the occurrences of each unique role
role_counts = cary_grant_roles['character'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
role_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Role')
plt.ylabel('Number of Occurrences')
plt.title('Number of Occurrences of Roles Played by Cary Grant')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the n-value of the roles that Sidney Poltier has acted over the years

# %%
sidney_poitier_roles = characters[characters['character'] == 'Sidney Poitier']

# Extract release years of the films
release_years = sidney_poitier_roles['year']

# Count the occurrences of roles for each year
role_counts_per_year = release_years.value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(12, 6))
role_counts_per_year.plot(kind='line', marker='o', color='skyblue')
plt.xlabel('year')
plt.ylabel('Number of Roles')
plt.title('Number of Roles Played by Sidney Poitier Over the Years')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
roles_1950s = characters[(characters['year'] >= 1950) & (characters['year'] <= 1959)]
actors_1950s = roles_1950s[roles_1950s['type'] == 'Male']
actresses_1950s = roles_1950s[roles_1950s['type'] == 'Female']
leading_roles_actors = len(actors_1950s[actors_1950s['type'] == 'Leading (n=1)'])
leading_roles_actresses = len(actresses_1950s[actresses_1950s['type'] == 'Leading (n=1)'])

print(f"Number of leading (n=1) roles for actors in the 1950s: {leading_roles_actors}")
print(f"Number of leading (n=1) roles for actresses in the 1950s: {leading_roles_actresses}")
# Out:
# Number of leading (n=1) roles for actors in the 1950s: 0
# Number of leading (n=1) roles for actresses in the 1950s: 0

# %% [markdown]
# # How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
roles_1950s = characters[(characters['year'] >= 1950) & (characters['year'] <= 1959)]

# Separate the dataset into actors and actresses
actors_1950s = roles_1950s[roles_1950s['type'] == 'Male']
actresses_1950s = roles_1950s[roles_1950s['type'] == 'Female']

# Count the number of supporting (n=2) roles for actors and actresses
supporting_roles_actors = len(actors_1950s[actors_1950s['type'] == 'Supporting (n=2)'])
supporting_roles_actresses = len(actresses_1950s[actresses_1950s['type'] == 'Supporting (n=2)'])

print(f"Number of supporting (n=2) roles for actors in the 1950s: {supporting_roles_actors}")
print(f"Number of supporting (n=2) roles for actresses in the 1950s: {supporting_roles_actresses}")
# Out:
# Number of supporting (n=2) roles for actors in the 1950s: 0
# Number of supporting (n=2) roles for actresses in the 1950s: 0
