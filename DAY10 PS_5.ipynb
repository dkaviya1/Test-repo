# %%
import pandas as pd
df=pd.read_csv("release_dates.csv")
df
# Out:
#                           title  year      country        date
# 0         #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                         #BKKY  2016     Cambodia  2017-10-12
# 2                       #Beings  2015      Romania  2015-01-29
# 3                     #Captured  2017          USA  2017-09-05
# 4        #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# ...                         ...   ...          ...         ...
# 479483  xXx: State of the Union  2005      Uruguay  2005-04-29
# 479484  xXx: State of the Union  2005       Poland  2005-06-03
# 479485  xXx: State of the Union  2005       Turkey  2005-06-03
# 479486  xXx: State of the Union  2005        China  2005-06-17
# 479487  xXx: State of the Union  2005       Greece  2005-06-24
#
# [479488 rows x 4 columns]

# %% [markdown]
# # Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
release_dates = pd.read_csv('release_dates.csv')
christmas_movies_usa = release_dates[(release_dates['title'].str.contains('Christmas', case=False)) & (release_dates['country'] == 'USA')]
christmas_movies_usa['month'] = pd.to_datetime(christmas_movies_usa['date']).dt.month_name()
monthly_counts = christmas_movies_usa['month'].value_counts()
monthly_counts = monthly_counts.reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
plt.figure(figsize=(10, 6))
monthly_counts.plot(kind='bar', color='green')
plt.xlabel('Month')
plt.ylabel('Number of Christmas Movies')
plt.title('Number of Christmas Movies Released Each Month in the USA')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13032\2635495777.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   christmas_movies_usa['month'] = pd.to_datetime(christmas_movies_usa['date']).dt.month_name()

# %% [markdown]
# # Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
release_dates = pd.read_csv('release_dates.csv')
hobbit_movies_usa = release_dates[(release_dates['title'].str.startswith('The Hobbit', na=False)) & (release_dates['country'] == 'USA')]
hobbit_movies_usa['month'] = pd.to_datetime(hobbit_movies_usa['date']).dt.month_name()
monthly_counts = hobbit_movies_usa['month'].value_counts()
monthly_counts = monthly_counts.reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
plt.figure(figsize=(10, 6))
monthly_counts.plot(kind='bar', color='blue')
plt.xlabel('Month')
plt.ylabel('Number of "The Hobbit" Movies')
plt.title('Number of "The Hobbit" Movies Released Each Month in the USA')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13032\389252010.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hobbit_movies_usa['month'] = pd.to_datetime(hobbit_movies_usa['date']).dt.month_name()

# %% [markdown]
# # Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA

# %%
release_dates = pd.read_csv('release_dates.csv')
romance_movies_usa = release_dates[(release_dates['title'].str.contains('Romance', case=False)) & (release_dates['country'] == 'USA')]
romance_movies_usa['date'] = pd.to_datetime(romance_movies_usa['date']).dt.day_name()
day_of_week_counts = romance_movies_usa['date'].value_counts()
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_of_week_counts = day_of_week_counts.reindex(days_of_week)
plt.figure(figsize=(10, 6))
day_of_week_counts.plot(kind='bar', color='pink')
plt.xlabel('Day of the Week')
plt.ylabel('Number of "Romance" Movies')
plt.title('Number of "Romance" Movies Released on Each Day of the Week in the USA')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13032\1470200681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   romance_movies_usa['date'] = pd.to_datetime(romance_movies_usa['date']).dt.day_name()

# %% [markdown]
# # Make a bar plot of the day of the week on which movies with "Action" In their title tend to be released in the USA.

# %%
release_dates = pd.read_csv('release_dates.csv')
action_movies_usa = release_dates[(release_dates['title'].str.contains('action', case=False)) & (release_dates['country'] == 'USA')]

# Extract the day of the week from the 'ReleaseDate' column
action_movies_usa['date'] = pd.to_datetime(action_movies_usa['date']).dt.day_name()

# Count the number of "Action" movies released on each day of the week
day_of_week_counts = action_movies_usa['date'].value_counts()

# Sort the days of the week in chronological order
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_of_week_counts = day_of_week_counts.reindex(days_of_week)

# Create a bar plot
plt.figure(figsize=(10, 6))
day_of_week_counts.plot(kind='bar', color='red')
plt.xlabel('Day of the Week')
plt.ylabel('Number of "Action" Movies')
plt.title('Number of "Action" Movies Released on Each Day of the Week in the USA')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13032\209505776.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   action_movies_usa['date'] = pd.to_datetime(action_movies_usa['date']).dt.day_name()

# %% [markdown]
# # On which date was each Judi Dench movie from the 1990s released in the USA?

# %%
release_dates = pd.read_csv('release_dates.csv')
judi_dench_1990s_usa = [release_dates(release_dates['title'].str.contains('Judi Dench', case=False)) &
                               (release_dates['date'].str.startswith('199')) &
                               (release_dates['country'] == 'USA')]
print("Judi Dench movies from the 1990s released in the USA:")
print(judi_dench_1990s_usa[['title', 'date']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 release_dates = pd.read_csv('release_dates.csv')
# ----> 2 judi_dench_1990s_usa = [release_dates(release_dates['title'].str.contains('Judi Dench', case=False)) &
#       3                                (release_dates['date'].str.startswith('199')) &
#       4                                (release_dates['country'] == 'USA')]
#       5 print("Judi Dench movies from the 1990s released in the USA:")
#       6 print(judi_dench_1990s_usa[['title', 'date']])
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# # In which months do films with Judi Dench tend to be released in the USA?

# %%
release_dates = pd.read_csv('release_dates.csv')
judi_dench_usa = release_dates [(release_dates ['title'].str.contains('Judi Dench', case=False)) &
                        (release_dates ['country'] == 'USA')]
judi_dench_usa['month'] = pd.to_datetime(judi_dench_usa['date']).dt.month_name()
monthly_counts = judi_dench_usa['month'].value_counts()
months_in_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
monthly_counts = monthly_counts.reindex(months_in_order)
print("Months in which films with Judi Dench tend to be released in the USA:")
print(monthly_counts)
# Out:
# Months in which films with Judi Dench tend to be released in the USA:
# January     NaN
# February    NaN
# March       NaN
# April       NaN
# May         NaN
# June        NaN
# July        NaN
# August      NaN
# September   NaN
# October     NaN
# November    NaN
# December    NaN
# Name: month, dtype: float64

# %% [markdown]
# # in which months do films with Tom Cruise tend to be released in the USA?

# %%
release_dates = pd.read_csv('release_dates.csv')
tom_cruise_usa = [release_dates(release_dates['title'].str.contains('Tom Cruise', case=False)) &
                        (release_dates['country'] == 'USA')]
tom_cruise_usa['ReleaseMonth'] = pd.to_datetime(tom_cruise_usa['date']).dt.month_name()
monthly_counts = tom_cruise_usa['ReleaseMonth'].value_counts()
months_in_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
monthly_counts = monthly_counts.reindex(months_in_order)
print("Months in which films with Tom Cruise tend to be released in the USA:")
print(monthly_counts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 release_dates = pd.read_csv('release_dates.csv')
# ----> 2 tom_cruise_usa = [release_dates(release_dates['title'].str.contains('Tom Cruise', case=False)) &
#       3                         (release_dates['country'] == 'USA')]
#       4 tom_cruise_usa['ReleaseMonth'] = pd.to_datetime(tom_cruise_usa['date']).dt.month_name()
#       5 monthly_counts = tom_cruise_usa['ReleaseMonth'].value_counts()
#
# TypeError: 'DataFrame' object is not callable
